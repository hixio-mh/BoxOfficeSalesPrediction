# %%
# %gui tk
# %run -i 'PredictionProgram.py'
# Out:
# Starting prediction on current Database
# Done with module 1
# Done with module 2
# Done with module 3
# Done with module 4
#            MovieName        Module 1       Module 2       Module 3  \
# 12          Deadpool   $158536099.92  $132447060.86   $62555284.43
# 16             Moana   $706800869.31   $56549742.45  $406768774.51
# 48         GameNight    $16935301.43   $23133566.30    $8787457.26
# 20             Venom    $64266784.79   $82178950.49    $7149347.97
# 7     Blackkklansman    $10332612.69   $16729900.98    $9032944.43
# 44           Hellboy     $7573232.29   $65639531.39   $11462227.39
# 49        QuietPlace     $9598866.17   $53519873.58   $13529092.93
# 43         JohnWick3    $60718496.95   $51150592.97   $55437484.15
# 46         Booksmart     $6073554.09   $23302901.00    $3281744.08
# 28             Logan    $22433784.09   $76030555.24   $18347039.36
# 34          Zootopia   $103843580.38   $85969164.98     $453706.92
# ...
